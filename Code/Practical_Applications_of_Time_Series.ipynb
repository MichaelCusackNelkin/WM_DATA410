# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# %%
series = pd.read_csv("Data/penguins.csv")
series
# Out:
#       Month  Number
# 0   2000-01     753
# 1   2000-02     448
# 2   2000-03     356
# 3   2000-04     504
# 4   2000-05     698
# ..      ...     ...
# 79  2006-08     301
# 80  2006-09     389
# 81  2006-10     624
# 82  2006-11     748
# 83  2006-12     842
#
# [84 rows x 2 columns]

# %%
series.plot(figsize=(8,8), fontsize=16)
plt.show()

# %% [markdown]
# ### Lomb Scargle Periodogram Next
