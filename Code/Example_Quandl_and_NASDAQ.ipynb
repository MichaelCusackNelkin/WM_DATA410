# %%
# !pip install quandl
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# ...

# %%
# !pip install Nasdaq-Data-Link
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mnelk\appdata\local\programs\python\python39\lib\site-packages)

# %%
# quandl for financial data
import quandl
# pandas for data manipulation
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns; sns.set()

# %%
quandl.ApiConfig.api_key = 'pURJLK7H4J6xc3NwcEo6'
# Retrieve APPLE data from Quandl
apple = quandl.get('WIKI/AAPL',trim_start = "2000-12-12", trim_end = "2021-12-30")
# Retrieve the Microsoft data from Quandl
ms = quandl.get('WIKI/MSFT',trim_start = "2000-12-12", trim_end = "2021-12-30")
ms
# Out:
#               Open    High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2000-12-12  57.810  60.000  56.75  58.38  31553000.0          0.0
# 2000-12-13  60.500  60.500  56.81  57.25  49180200.0          0.0
# 2000-12-14  57.940  58.730  55.38  55.50  35600700.0          0.0
# 2000-12-15  51.050  52.000  47.75  49.19  58449900.0          0.0
# 2000-12-18  49.000  50.000  47.00  47.81  53593700.0          0.0
# ...            ...     ...    ...    ...         ...          ...
# 2018-03-21  92.930  94.050  92.21  92.48  23753263.0          0.0
# 2018-03-22  91.265  91.750  89.66  89.79  37578166.0          0.0
# 2018-03-23  89.500  90.460  87.08  87.18  42159397.0          0.0
# 2018-03-26  90.610  94.000  90.40  93.78  55031149.0          0.0
# 2018-03-27  94.940  95.139  88.51  89.47  53704562.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2000-12-12          1.0  19.241805  19.970737  18.888988   19.431527
# ...

# %%
ms.iloc[-1,:]
# Out:
# Open           9.494000e+01
# High           9.513900e+01
# Low            8.851000e+01
# Close          8.947000e+01
# Volume         5.370456e+07
# Ex-Dividend    0.000000e+00
# Split Ratio    1.000000e+00
# Adj. Open      9.494000e+01
# Adj. High      9.513900e+01
# Adj. Low       8.851000e+01
# Adj. Close     8.947000e+01
# Adj. Volume    5.370456e+07
# Name: 2018-03-27 00:00:00, dtype: float64

# %%
apple.head(5)
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 2000-12-12  15.25  16.00  15.00  15.38  6897500.0          0.0          1.0
# 2000-12-13  15.56  15.56  14.88  15.00  6158700.0          0.0          1.0
# 2000-12-14  15.03  15.25  14.44  14.44  4702100.0          0.0          1.0
# 2000-12-15  14.56  14.69  14.00  14.06  9177600.0          0.0          1.0
# 2000-12-18  14.56  14.63  13.94  14.25  5818000.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2000-12-12   0.979919   1.028112  0.963855    0.988272   96565000.0
# 2000-12-13   0.999838   0.999838  0.956144    0.963855   86221800.0
# 2000-12-14   0.965782   0.979919  0.927871    0.927871   65829400.0
# 2000-12-15   0.935581   0.943935  0.899598    0.903453  128486400.0
# 2000-12-18   0.935581   0.940079  0.895742    0.915662   81452000.0

# %%
# %matplotlib inline
#%config InlineBackend.figure_format = 'retina'

# %%
# The adjusted close accounts for stock splits, so that is what we should graph
fig,ax = plt.subplots(figsize=(6,4))
plt.plot(ms.index, ms['Adj. Close'])
plt.title('Microsoft Stock Price')
plt.ylabel('Price ($)');
plt.show()

fig,ax = plt.subplots(figsize=(6,4))
plt.plot(apple.index, apple['Adj. Close'], 'r')
plt.title('Apple Stock Price')
plt.ylabel('Price ($)');
plt.show();

# %%
intel = quandl.get('WIKI/INTc')
intel
# Out:
#              Open   High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-03-17  62.50  63.50  62.50  62.50     56900.0          0.0          1.0
# 1980-03-18  62.50  63.00  62.00  62.00     88900.0          0.0          1.0
# 1980-03-19  63.50  64.50  63.50  63.50     96400.0          0.0          1.0
# 1980-03-20  63.50  64.25  63.25  63.25     58200.0          0.0          1.0
# 1980-03-21  62.00  62.00  61.00  61.00     63400.0          0.0          1.0
# ...           ...    ...    ...    ...         ...          ...          ...
# 2018-03-21  51.55  52.17  51.17  51.56  22984769.0          0.0          1.0
# 2018-03-22  50.74  51.96  50.60  50.83  30650151.0          0.0          1.0
# 2018-03-23  50.59  50.99  49.36  49.36  36741700.0          0.0          1.0
# 2018-03-26  50.74  52.49  50.32  52.48  37527480.0          0.0          1.0
# 2018-03-27  53.01  53.25  50.78  51.19  37076576.0          0.0          1.0
#
# ...

# %%
fig,ax = plt.subplots(figsize=(12,10))
plt.plot(intel.index, intel['Adj. Close'])
plt.title('Intel Stock Price')
plt.ylabel('Price ($)');
plt.show()

# %%
import nasdaqdatalink
mydata = nasdaqdatalink.get("FRED/GDP")
mydata
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
# 2021-10-01  23992.355
#
# [300 rows x 1 columns]

# %%
data = nasdaqdatalink.get('NSE/OIL', start_date="2001-12-31", end_date="20021-12-31")
data
# Out:
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2009-09-30  1096.00  1156.70  1090.00  1135.00  1141.20            19748012.0
# 2009-10-01  1102.00  1173.70  1102.00  1167.00  1166.35             3074254.0
# 2009-10-05  1152.00  1165.90  1136.60  1143.00  1140.55              919832.0
# 2009-10-06  1149.80  1157.20  1132.10  1143.30  1144.90              627957.0
# 2009-10-07  1153.80  1160.70  1140.00  1141.45  1141.60              698216.0
# ...             ...      ...      ...      ...      ...                   ...
# 2018-12-31   178.10   179.00   174.35   175.00   174.80              761462.0
# 2019-01-01   175.00   176.40   174.15   175.15   175.75              381570.0
# 2019-01-02   175.80   176.20   171.00   172.35   172.40              722532.0
# 2019-01-03   172.80   175.70   171.50   172.00   172.00              698190.0
# 2019-01-04   172.05   174.95   172.05   174.55   174.55              431122.0
#
# ...
